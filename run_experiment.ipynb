# %% [raw]
# # 🧪 **TOURNAMENT EXPERIMENT RUNNER**
#
# Clean interface for running large-scale tournament experiments.
#
# **Features:**
# - Auto-randomized tournament sizes (3,700-4,000 players)
# - Complete data tracking in database
# - Streamlined logging for large experiments
# - Championship points cutoff analysis

# %%
# Initialize the tournament simulator
from clean_tournament_sim import TournamentSimulator
from player_database import PlayerDatabase

sim = TournamentSimulator()
db = PlayerDatabase()
players = db.load_all_players()

print("🎮 Tournament Simulator Ready!")
print(f"📊 Database contains {len(players):,} players")

# Show player composition
jp_players = [p for p in players if hasattr(p, 'rating_zone') and p.rating_zone == 'JP']
na_players = [p for p in players if not hasattr(p, 'rating_zone') or p.rating_zone == 'NA']
core_field = players[:3700]
variable_field = players[3700:]

print(f"\n🎯 Database Composition:")
print(f"   • JP players (800 CP): {len(jp_players)}")
print(f"   • NA players: {len(na_players):,}")
print(f"   • Core field (1-3700): {len(core_field):,} players")
print(f"   • Variable field (3701-4000): {len(variable_field)} players (all low-CP NA)")
print(f"\n✅ Ready for tournaments with 3,700-4,000 players!")
print("   When tournament size varies, extra players come from low-CP NA pool")
# Out:
# 📊 Loaded 544 NA players from standings
# 🎮 Tournament Simulator Ready!
# 📊 Database contains 4,000 players
#
# 🎯 Database Composition:
#    • JP players (800 CP): 50
#    • NA players: 3,950
#    • Core field (1-3700): 3,700 players
#    • Variable field (3701-4000): 300 players (all low-CP NA)
#
# ✅ Ready for tournaments with 3,700-4,000 players!
#    When tournament size varies, extra players come from low-CP NA pool

# %% [raw]
# ## 🚀 **QUICK EXPERIMENTS**
#
# Run small batches to test or get quick results.

# %%
# Run 10 tournaments with random sizes (3,700-4,000 each)
results = sim.run_multiple_quick(num_tournaments=79, verbose=True, save_results=True)
# Out:
# 🚀 RUNNING 79 TOURNAMENTS
# 🎮 Tournament 1/79... 📊 FIELD COMPOSITION:
#    Total: 3,719 players
#    Low CP (≤331): 3,069 (82.5%)
#    Real players (≥332): 650 (17.5%)
# Champion: Ethan Hegyi (779 CP) 💎
# 🎮 Tournament 2/79... 📊 FIELD COMPOSITION:
#    Total: 3,848 players
#    Low CP (≤331): 3,198 (83.1%)
#    Real players (≥332): 650 (16.9%)
# Champion: Caleb Rogerson (1589 CP) 💎
# 🎮 Tournament 3/79... 📊 FIELD COMPOSITION:
#    Total: 3,763 players
#    Low CP (≤331): 3,113 (82.7%)
#    Real players (≥332): 650 (17.3%)
# Champion: Alex Chandler (696 CP) 💎
# 🎮 Tournament 4/79... 📊 FIELD COMPOSITION:
#    Total: 3,929 players
#    Low CP (≤331): 3,279 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: CHARIZARDMT (794 CP) 💎
# 🎮 Tournament 5/79... 📊 FIELD COMPOSITION:
#    Total: 3,771 players
#    Low CP (≤331): 3,121 (82.8%)
#    Real players (≥332): 650 (17.2%)
# Champion: Isaiah C (776 CP) 💎
# 🎮 Tournament 6/79... 📊 FIELD COMPOSITION:
#    Total: 3,948 players
#    Low CP (≤331): 3,298 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: Ross Cawthon (750 CP) 💎
# 🎮 Tournament 7/79... 📊 FIELD COMPOSITION:
#    Total: 3,783 players
#    Low CP (≤331): 3,133 (82.8%)
#    Real players (≥332): 650 (17.2%)
# Champion: CHARIZARDMT (794 CP) 💎
# 🎮 Tournament 8/79... 📊 FIELD COMPOSITION:
#    Total: 3,981 players
#    Low CP (≤331): 3,331 (83.7%)
#    Real players (≥332): 650 (16.3%)
# Champion: Austin Charles (680 CP) 💎
# 🎮 Tournament 9/79... 📊 FIELD COMPOSITION:
#    Total: 3,881 players
#    Low CP (≤331): 3,231 (83.3%)
#    Real players (≥332): 650 (16.7%)
# Champion: zach lesage (800 CP) 💎
# 🎮 Tournament 10/79... 📊 FIELD COMPOSITION:
#    Total: 3,757 players
#    Low CP (≤331): 3,107 (82.7%)
#    Real players (≥332): 650 (17.3%)
# Champion: Grant Manley (1110 CP) 💎
# 🎮 Tournament 11/79... 📊 FIELD COMPOSITION:
#    Total: 3,792 players
#    Low CP (≤331): 3,142 (82.9%)
#    Real players (≥332): 650 (17.1%)
# Champion: Grant S (1267 CP) 💎
# 🎮 Tournament 12/79... 📊 FIELD COMPOSITION:
#    Total: 3,833 players
#    Low CP (≤331): 3,183 (83.0%)
#    Real players (≥332): 650 (17.0%)
# Champion: Nolan Randall (750 CP) 💎
# 🎮 Tournament 13/79... 📊 FIELD COMPOSITION:
#    Total: 3,849 players
#    Low CP (≤331): 3,199 (83.1%)
#    Real players (≥332): 650 (16.9%)
# Champion: simon trottier (695 CP) 💎
# 🎮 Tournament 14/79... 📊 FIELD COMPOSITION:
#    Total: 3,853 players
#    Low CP (≤331): 3,203 (83.1%)
#    Real players (≥332): 650 (16.9%)
# Champion: Nicholas Moffitt (820 CP) 💎
# 🎮 Tournament 15/79... 📊 FIELD COMPOSITION:
#    Total: 3,890 players
#    Low CP (≤331): 3,240 (83.3%)
#    Real players (≥332): 650 (16.7%)
# Champion: Drew Hedrick (1339 CP) 💎
# 🎮 Tournament 16/79... 📊 FIELD COMPOSITION:
#    Total: 3,876 players
#    Low CP (≤331): 3,226 (83.2%)
#    Real players (≥332): 650 (16.8%)
# Champion: Simon Feng (822 CP) 💎
# 🎮 Tournament 17/79... 📊 FIELD COMPOSITION:
#    Total: 3,712 players
#    Low CP (≤331): 3,062 (82.5%)
#    Real players (≥332): 650 (17.5%)
# Champion: Michael Davidson (1500 CP) 💎
# 🎮 Tournament 18/79... 📊 FIELD COMPOSITION:
#    Total: 3,795 players
#    Low CP (≤331): 3,145 (82.9%)
#    Real players (≥332): 650 (17.1%)
# Champion: Christian LaBella (1228 CP) 💎
# 🎮 Tournament 19/79... 📊 FIELD COMPOSITION:
#    Total: 4,000 players
#    Low CP (≤331): 3,350 (83.8%)
#    Real players (≥332): 650 (16.2%)
# Champion: Benny Billinger (974 CP) 💎
# 🎮 Tournament 20/79... 📊 FIELD COMPOSITION:
#    Total: 3,983 players
#    Low CP (≤331): 3,333 (83.7%)
#    Real players (≥332): 650 (16.3%)
# Champion: Jackson Ford (1105 CP) 💎
# 🎮 Tournament 21/79... 📊 FIELD COMPOSITION:
#    Total: 3,930 players
#    Low CP (≤331): 3,280 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: Ryo Sakamoto (650 CP) 💎
# 🎮 Tournament 22/79... 📊 FIELD COMPOSITION:
#    Total: 3,855 players
#    Low CP (≤331): 3,205 (83.1%)
#    Real players (≥332): 650 (16.9%)
# Champion: Christopher B (700 CP) 💎
# 🎮 Tournament 23/79... 📊 FIELD COMPOSITION:
#    Total: 3,786 players
#    Low CP (≤331): 3,136 (82.8%)
#    Real players (≥332): 650 (17.2%)
# Champion: Henry Chao (1738 CP) 💎
# 🎮 Tournament 24/79... 📊 FIELD COMPOSITION:
#    Total: 3,941 players
#    Low CP (≤331): 3,291 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: blake w (740 CP) 💎
# 🎮 Tournament 25/79... 📊 FIELD COMPOSITION:
#    Total: 3,702 players
#    Low CP (≤331): 3,052 (82.4%)
#    Real players (≥332): 650 (17.6%)
# Champion: nathian beck (736 CP) 💎
# 🎮 Tournament 26/79... 📊 FIELD COMPOSITION:
#    Total: 3,739 players
#    Low CP (≤331): 3,089 (82.6%)
#    Real players (≥332): 650 (17.4%)
# Champion: Adam Reinhardt (665 CP) 💎
# 🎮 Tournament 27/79... 📊 FIELD COMPOSITION:
#    Total: 3,912 players
#    Low CP (≤331): 3,262 (83.4%)
#    Real players (≥332): 650 (16.6%)
# Champion: Cyrus McCane (700 CP) 💎
# 🎮 Tournament 28/79... 📊 FIELD COMPOSITION:
#    Total: 3,789 players
#    Low CP (≤331): 3,139 (82.8%)
#    Real players (≥332): 650 (17.2%)
# Champion: Tdtipton07 (720 CP) 💎
# 🎮 Tournament 29/79... 📊 FIELD COMPOSITION:
#    Total: 3,949 players
#    Low CP (≤331): 3,299 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: lucas xing (1235 CP) 💎
# 🎮 Tournament 30/79... 📊 FIELD COMPOSITION:
#    Total: 3,913 players
#    Low CP (≤331): 3,263 (83.4%)
#    Real players (≥332): 650 (16.6%)
# Champion: Steven Varesko (782 CP) 💎
# 🎮 Tournament 31/79... 📊 FIELD COMPOSITION:
#    Total: 3,977 players
#    Low CP (≤331): 3,327 (83.7%)
#    Real players (≥332): 650 (16.3%)
# Champion: Gabriel Smart (1330 CP) 💎
# 🎮 Tournament 32/79... 📊 FIELD COMPOSITION:
#    Total: 3,775 players
#    Low CP (≤331): 3,125 (82.8%)
#    Real players (≥332): 650 (17.2%)
# Champion: Michael Meal (730 CP) 💎
# 🎮 Tournament 33/79... 📊 FIELD COMPOSITION:
#    Total: 3,931 players
#    Low CP (≤331): 3,281 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: Adam Reinhardt (665 CP) 💎
# 🎮 Tournament 34/79... 📊 FIELD COMPOSITION:
#    Total: 3,767 players
#    Low CP (≤331): 3,117 (82.7%)
#    Real players (≥332): 650 (17.3%)
# Champion: Owen Dalgard (1525 CP) 💎
# 🎮 Tournament 35/79... 📊 FIELD COMPOSITION:
#    Total: 3,975 players
#    Low CP (≤331): 3,325 (83.6%)
#    Real players (≥332): 650 (16.4%)
# Champion: Rahul Reddy (1525 CP) 💎
# 🎮 Tournament 36/79... 📊 FIELD COMPOSITION:
#    Total: 3,851 players
#    Low CP (≤331): 3,201 (83.1%)
#    Real players (≥332): 650 (16.9%)
# Champion: RAMIRO GALINDO (662 CP) 💎
# 🎮 Tournament 37/79... 📊 FIELD COMPOSITION:
#    Total: 3,727 players
#    Low CP (≤331): 3,077 (82.6%)
#    Real players (≥332): 650 (17.4%)
# Champion: Abaan A (1120 CP) 💎
# 🎮 Tournament 38/79... 📊 FIELD COMPOSITION:
#    Total: 3,753 players
#    Low CP (≤331): 3,103 (82.7%)
#    Real players (≥332): 650 (17.3%)
# Champion: Naoki Fujii (650 CP) 💎
# 🎮 Tournament 39/79... 📊 FIELD COMPOSITION:
#    Total: 3,738 players
#    Low CP (≤331): 3,088 (82.6%)
#    Real players (≥332): 650 (17.4%)
# Champion: zach lesage (800 CP) 💎
# 🎮 Tournament 40/79... 📊 FIELD COMPOSITION:
#    Total: 3,809 players
#    Low CP (≤331): 3,159 (82.9%)
#    Real players (≥332): 650 (17.1%)
# Champion: Samuel Scime (740 CP) 💎
# 🎮 Tournament 41/79... 📊 FIELD COMPOSITION:
#    Total: 3,770 players
#    Low CP (≤331): 3,120 (82.8%)
#    Real players (≥332): 650 (17.2%)
# Champion: Grant Manley (1110 CP) 💎
# 🎮 Tournament 42/79... 📊 FIELD COMPOSITION:
#    Total: 3,903 players
#    Low CP (≤331): 3,253 (83.3%)
#    Real players (≥332): 650 (16.7%)
# Champion: Cory Tangman (592 CP) 💎
# 🎮 Tournament 43/79... 📊 FIELD COMPOSITION:
#    Total: 3,741 players
#    Low CP (≤331): 3,091 (82.6%)
#    Real players (≥332): 650 (17.4%)
# Champion: Trevore Read (760 CP) 💎
# 🎮 Tournament 44/79... 📊 FIELD COMPOSITION:
#    Total: 3,718 players
#    Low CP (≤331): 3,068 (82.5%)
#    Real players (≥332): 650 (17.5%)
# Champion: Rahul Reddy (1525 CP) 💎
# 🎮 Tournament 45/79... 📊 FIELD COMPOSITION:
#    Total: 3,858 players
#    Low CP (≤331): 3,208 (83.2%)
#    Real players (≥332): 650 (16.8%)
# Champion: Matt Chuang (820 CP) 💎
# 🎮 Tournament 46/79... 📊 FIELD COMPOSITION:
#    Total: 3,808 players
#    Low CP (≤331): 3,158 (82.9%)
#    Real players (≥332): 650 (17.1%)
# Champion: Caleb Rogerson (1589 CP) 💎
# 🎮 Tournament 47/79... 📊 FIELD COMPOSITION:
#    Total: 3,719 players
#    Low CP (≤331): 3,069 (82.5%)
#    Real players (≥332): 650 (17.5%)
# Champion: Taiga Shimizu (650 CP) 💎
# 🎮 Tournament 48/79... 📊 FIELD COMPOSITION:
#    Total: 3,804 players
#    Low CP (≤331): 3,154 (82.9%)
#    Real players (≥332): 650 (17.1%)
# Champion: JOSE ZELAYA (737 CP) 💎
# 🎮 Tournament 49/79... 📊 FIELD COMPOSITION:
#    Total: 3,802 players
#    Low CP (≤331): 3,152 (82.9%)
#    Real players (≥332): 650 (17.1%)
# Champion: Rowan Stavenow (1097 CP) 💎
# 🎮 Tournament 50/79... 📊 FIELD COMPOSITION:
#    Total: 3,965 players
#    Low CP (≤331): 3,315 (83.6%)
#    Real players (≥332): 650 (16.4%)
# Champion: Phoenix White (1275 CP) 💎
# 🎮 Tournament 51/79... 📊 FIELD COMPOSITION:
#    Total: 3,848 players
#    Low CP (≤331): 3,198 (83.1%)
#    Real players (≥332): 650 (16.9%)
# Champion: Eric Ridgeway (600 CP) 💎
# 🎮 Tournament 52/79... 📊 FIELD COMPOSITION:
#    Total: 3,833 players
#    Low CP (≤331): 3,183 (83.0%)
#    Real players (≥332): 650 (17.0%)
# Champion: Michael Meal (730 CP) 💎
# 🎮 Tournament 53/79... 📊 FIELD COMPOSITION:
#    Total: 3,869 players
#    Low CP (≤331): 3,219 (83.2%)
#    Real players (≥332): 650 (16.8%)
# Champion: Joshua Frink (747 CP) 💎
# 🎮 Tournament 54/79... 📊 FIELD COMPOSITION:
#    Total: 3,994 players
#    Low CP (≤331): 3,344 (83.7%)
#    Real players (≥332): 650 (16.3%)
# Champion: Henry Thompson (725 CP) 💎
# 🎮 Tournament 55/79... 📊 FIELD COMPOSITION:
#    Total: 3,724 players
#    Low CP (≤331): 3,074 (82.5%)
#    Real players (≥332): 650 (17.5%)
# Champion: Rei Kobayashi (650 CP) 💎
# 🎮 Tournament 56/79... 📊 FIELD COMPOSITION:
#    Total: 3,823 players
#    Low CP (≤331): 3,173 (83.0%)
#    Real players (≥332): 650 (17.0%)
# Champion: David Zheng (805 CP) 💎
# 🎮 Tournament 57/79... 📊 FIELD COMPOSITION:
#    Total: 3,757 players
#    Low CP (≤331): 3,107 (82.7%)
#    Real players (≥332): 650 (17.3%)
# Champion: Grant S (1267 CP) 💎
# 🎮 Tournament 58/79... 📊 FIELD COMPOSITION:
#    Total: 3,959 players
#    Low CP (≤331): 3,309 (83.6%)
#    Real players (≥332): 650 (16.4%)
# Champion: Vince Owen (1117 CP) 💎
# 🎮 Tournament 59/79... 📊 FIELD COMPOSITION:
#    Total: 3,818 players
#    Low CP (≤331): 3,168 (83.0%)
#    Real players (≥332): 650 (17.0%)
# Champion: Grant S (1267 CP) 💎
# 🎮 Tournament 60/79... 📊 FIELD COMPOSITION:
#    Total: 3,758 players
#    Low CP (≤331): 3,108 (82.7%)
#    Real players (≥332): 650 (17.3%)
# Champion: Alex Chandler (696 CP) 💎
# 🎮 Tournament 61/79... 📊 FIELD COMPOSITION:
#    Total: 3,928 players
#    Low CP (≤331): 3,278 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: Sebastian L (1285 CP) 💎
# 🎮 Tournament 62/79... 📊 FIELD COMPOSITION:
#    Total: 3,767 players
#    Low CP (≤331): 3,117 (82.7%)
#    Real players (≥332): 650 (17.3%)
# Champion: JUAN FLORES (550 CP) 💎
# 🎮 Tournament 63/79... 📊 FIELD COMPOSITION:
#    Total: 3,710 players
#    Low CP (≤331): 3,060 (82.5%)
#    Real players (≥332): 650 (17.5%)
# Champion: Owen Dalgard (1525 CP) 💎
# 🎮 Tournament 64/79... 📊 FIELD COMPOSITION:
#    Total: 3,903 players
#    Low CP (≤331): 3,253 (83.3%)
#    Real players (≥332): 650 (16.7%)
# Champion: Steven Varesko (782 CP) 💎
# 🎮 Tournament 65/79... 📊 FIELD COMPOSITION:
#    Total: 3,952 players
#    Low CP (≤331): 3,302 (83.6%)
#    Real players (≥332): 650 (16.4%)
# Champion: Henry Thompson (725 CP) 💎
# 🎮 Tournament 66/79... 📊 FIELD COMPOSITION:
#    Total: 3,981 players
#    Low CP (≤331): 3,331 (83.7%)
#    Real players (≥332): 650 (16.3%)
# Champion: Ethan Hegyi (779 CP) 💎
# 🎮 Tournament 67/79... 📊 FIELD COMPOSITION:
#    Total: 3,908 players
#    Low CP (≤331): 3,258 (83.4%)
#    Real players (≥332): 650 (16.6%)
# Champion: blake w (740 CP) 💎
# 🎮 Tournament 68/79... 📊 FIELD COMPOSITION:
#    Total: 3,980 players
#    Low CP (≤331): 3,330 (83.7%)
#    Real players (≥332): 650 (16.3%)
# Champion: James Kowalski (780 CP) 💎
# 🎮 Tournament 69/79... 📊 FIELD COMPOSITION:
#    Total: 3,877 players
#    Low CP (≤331): 3,227 (83.2%)
#    Real players (≥332): 650 (16.8%)
# Champion: aiden toler (540 CP) 💎
# 🎮 Tournament 70/79... 📊 FIELD COMPOSITION:
#    Total: 3,951 players
#    Low CP (≤331): 3,301 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: Saumit Kukkadapu (840 CP) 💎
# 🎮 Tournament 71/79... 📊 FIELD COMPOSITION:
#    Total: 3,903 players
#    Low CP (≤331): 3,253 (83.3%)
#    Real players (≥332): 650 (16.7%)
# Champion: Christian LaBella (1228 CP) 💎
# 🎮 Tournament 72/79... 📊 FIELD COMPOSITION:
#    Total: 3,941 players
#    Low CP (≤331): 3,291 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: Joseph Figliano (750 CP) 💎
# 🎮 Tournament 73/79... 📊 FIELD COMPOSITION:
#    Total: 3,880 players
#    Low CP (≤331): 3,230 (83.2%)
#    Real players (≥332): 650 (16.8%)
# Champion: Rahul Reddy (1525 CP) 💎
# 🎮 Tournament 74/79... 📊 FIELD COMPOSITION:
#    Total: 3,936 players
#    Low CP (≤331): 3,286 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: Xander Pero (740 CP) 💎
# 🎮 Tournament 75/79... 📊 FIELD COMPOSITION:
#    Total: 3,855 players
#    Low CP (≤331): 3,205 (83.1%)
#    Real players (≥332): 650 (16.9%)
# Champion: Henry Thompson (725 CP) 💎
# 🎮 Tournament 76/79... 📊 FIELD COMPOSITION:
#    Total: 3,887 players
#    Low CP (≤331): 3,237 (83.3%)
#    Real players (≥332): 650 (16.7%)
# Champion: Christian LaBella (1228 CP) 💎
# 🎮 Tournament 77/79... 📊 FIELD COMPOSITION:
#    Total: 3,935 players
#    Low CP (≤331): 3,285 (83.5%)
#    Real players (≥332): 650 (16.5%)
# Champion: Simon Feng (822 CP) 💎
# 🎮 Tournament 78/79... 📊 FIELD COMPOSITION:
#    Total: 3,927 players
#    Low CP (≤331): 3,277 (83.4%)
#    Real players (≥332): 650 (16.6%)
# Champion: Austin Charles (680 CP) 💎
# 🎮 Tournament 79/79... 📊 FIELD COMPOSITION:
#    Total: 3,758 players
#    Low CP (≤331): 3,108 (82.7%)
#    Real players (≥332): 650 (17.3%)
# Champion: Abaan A (1120 CP) 💎
#
# 📈 SUMMARY: 79 tournaments | Avg size: 3851 players | Low CP champions: 0/79 (0.0%)

# %% [raw]
# ## 🎯 **LARGE SCALE EXPERIMENT**
#
# Run 100-1000+ tournaments for comprehensive analysis.

# %%
# LARGE EXPERIMENT - Adjust num_tournaments as needed
num_tournaments = 100  # Change this: 100, 500, 1000, etc.

print(f"🧪 Starting large experiment: {num_tournaments} tournaments")
print(f"📈 Each tournament: 3,700-4,000 players (randomized)")
print(f"⏱️ Estimated time: ~{num_tournaments * 2} seconds\n")

# Run the experiment
large_results = sim.run_multiple_quick(num_tournaments=num_tournaments, verbose=False)

print(f"\n✅ EXPERIMENT COMPLETE!")
print(f"🎮 {len(large_results)} tournaments simulated")
print(f"💾 All data saved to database")

# %% [raw]
# ## 📊 **CHAMPIONSHIP POINTS CUTOFF ANALYSIS**
#
# Analyze where the 140th place cutoff lands after multiple tournaments.

# %%
# 🎯 **140TH PLACE CUTOFF ANALYSIS - FROM EXISTING TOURNAMENTS**
# =================================================================
# Analyze the 140th place cutoff from tournaments already saved in database

from analyze_existing_140th import analyze_140th_place_from_database

print("🎯 Analyzing 140th place cutoff from existing tournament data...")
results = analyze_140th_place_from_database()

if results:
    # Quick access to key statistics
    stats = results['statistics']
    print(f"\n📋 QUICK SUMMARY:")
    print(f"   Tournaments analyzed: {stats['num_tournaments']}")
    print(f"   Baseline 140th place: {stats['baseline']:,} CP")
    print(f"   Cutoff range: {stats['min']:,} - {stats['max']:,} CP")
    print(f"   Average cutoff: {stats['mean']:,.1f} CP ± {stats['std']:.1f}")
    print(f"   Most likely cutoff: {stats['median']:,.0f} CP")
    
    # Store results for further analysis
    cutoff_stats = stats
    cutoff_values = results['raw_data']
    
    print(f"\n✅ Results stored in variables 'cutoff_stats' and 'cutoff_values'")
    print(f"💾 Detailed files saved with timestamp")
else:
    print("❌ Analysis failed - check database")
# Out:
# 🎯 Analyzing 140th place cutoff from existing tournament data...
# 🎯 ANALYZING 140TH PLACE CUTOFF FROM EXISTING TOURNAMENTS
# ============================================================
# 📊 Loaded 544 NA players from standings
# 📊 Baseline 140th place: Ramiro Galindo with 662 CP
# 📋 Found 100 tournaments in database
#
# 🏆 Analyzing Tournament 1/100: tournament_20250609_161141
#    140th place: DC DeVos with 707 CP (+45)
#
# 🏆 Analyzing Tournament 2/100: tournament_20250609_161320
#    140th place: Justin Kim with 715 CP (+53)
#
# 🏆 Analyzing Tournament 3/100: tournament_20250609_161523
#    140th place: George Illidge with 720 CP (+58)
#
# 🏆 Analyzing Tournament 4/100: tournament_20250609_161655
#    140th place: Ajay Sridhar with 712 CP (+50)
#
# 🏆 Analyzing Tournament 5/100: tournament_20250609_161740
#    140th place: Dre Alderette with 720 CP (+58)
#
# 🏆 Analyzing Tournament 6/100: tournament_20250609_161800
#    140th place: Christian Chase with 720 CP (+58)
#
# 🏆 Analyzing Tournament 7/100: tournament_20250609_161821
#    140th place: Sanjay Sundararajan with 720 CP (+58)
#
# 🏆 Analyzing Tournament 8/100: tournament_20250609_162247
#    140th place: Hunter Butler with 720 CP (+58)
#
# 🏆 Analyzing Tournament 9/100: tournament_20250609_162424
#    140th place: Ramiro Galindo with 662 CP (+0)
#
# 🏆 Analyzing Tournament 10/100: tournament_20250609_162737
#    140th place: Dre Alderette with 720 CP (+58)
#
# 🏆 Analyzing Tournament 11/100: tournament_20250609_162759
#    140th place: Jeremy Medina with 700 CP (+38)
#
# 🏆 Analyzing Tournament 12/100: tournament_20250609_162818
#    140th place: Mustafa Tobah with 717 CP (+55)
#
# 🏆 Analyzing Tournament 13/100: tournament_20250609_162838
#    140th place: jesse spencer with 719 CP (+57)
#
# 🏆 Analyzing Tournament 14/100: tournament_20250609_162858
#    140th place: Richard Yannow with 715 CP (+53)
#
# 🏆 Analyzing Tournament 15/100: tournament_20250609_162918
#    140th place: Ethan Yi with 720 CP (+58)
#
# 🏆 Analyzing Tournament 16/100: tournament_20250609_162939
#    140th place: Pearce Blend with 725 CP (+63)
#
# 🏆 Analyzing Tournament 17/100: tournament_20250609_163000
#    140th place: Jeremiah Schmutz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 18/100: tournament_20250609_163019
#    140th place: Aaron Curry with 720 CP (+58)
#
# 🏆 Analyzing Tournament 19/100: tournament_20250609_163039
#    140th place: Vance Kelley with 714 CP (+52)
#
# 🏆 Analyzing Tournament 20/100: tournament_20250609_163607
#    140th place: Asher Johnson with 720 CP (+58)
#
# 🏆 Analyzing Tournament 21/100: tournament_20250609_163627
#    140th place: Jon Bieligk with 725 CP (+63)
#
# 🏆 Analyzing Tournament 22/100: tournament_20250609_163702
#    140th place: Ajay Sridhar with 712 CP (+50)
#
# 🏆 Analyzing Tournament 23/100: tournament_20250609_163723
#    140th place: Dre Alderette with 720 CP (+58)
#
# 🏆 Analyzing Tournament 24/100: tournament_20250609_163748
#    140th place: Hunter Butler with 720 CP (+58)
#
# 🏆 Analyzing Tournament 25/100: tournament_20250609_163813
#    140th place: Ethan Yi with 720 CP (+58)
#
# 🏆 Analyzing Tournament 26/100: tournament_20250609_163838
#    140th place: Eric Ridgeway with 710 CP (+48)
#
# 🏆 Analyzing Tournament 27/100: tournament_20250609_163904
#    140th place: Ramiro Galindo with 702 CP (+40)
#
# 🏆 Analyzing Tournament 28/100: tournament_20250609_163928
#    140th place: Jeremiah Schmutz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 29/100: tournament_20250609_163952
#    140th place: Mustafa Tobah with 717 CP (+55)
#
# 🏆 Analyzing Tournament 30/100: tournament_20250609_164016
#    140th place: Orlando Karam with 717 CP (+55)
#
# 🏆 Analyzing Tournament 31/100: tournament_20250609_164040
#    140th place: Cameron Kawasaki with 720 CP (+58)
#
# 🏆 Analyzing Tournament 32/100: tournament_20250609_164105
#    140th place: Hunter Butler with 720 CP (+58)
#
# 🏆 Analyzing Tournament 33/100: tournament_20250609_164130
#    140th place: Frank Luciano with 720 CP (+58)
#
# 🏆 Analyzing Tournament 34/100: tournament_20250609_164156
#    140th place: Tiger Hickman with 720 CP (+58)
#
# 🏆 Analyzing Tournament 35/100: tournament_20250609_164222
#    140th place: Ethan Yi with 720 CP (+58)
#
# 🏆 Analyzing Tournament 36/100: tournament_20250609_164247
#    140th place: Christian Chase with 720 CP (+58)
#
# 🏆 Analyzing Tournament 37/100: tournament_20250609_164313
#    140th place: Dre Alderette with 720 CP (+58)
#
# 🏆 Analyzing Tournament 38/100: tournament_20250609_164340
#    140th place: Joseph Nawal with 720 CP (+58)
#
# 🏆 Analyzing Tournament 39/100: tournament_20250609_164405
#    140th place: Eric Ridgeway with 710 CP (+48)
#
# 🏆 Analyzing Tournament 40/100: tournament_20250609_164432
#    140th place: Joseph Nawal with 720 CP (+58)
#
# 🏆 Analyzing Tournament 41/100: tournament_20250609_164501
#    140th place: Dre Alderette with 720 CP (+58)
#
# 🏆 Analyzing Tournament 42/100: tournament_20250609_164529
#    140th place: Joseph Nawal with 720 CP (+58)
#
# 🏆 Analyzing Tournament 43/100: tournament_20250609_164557
#    140th place: Yihao Chen with 720 CP (+58)
#
# 🏆 Analyzing Tournament 44/100: tournament_20250609_164624
#    140th place: Ajay Sridhar with 712 CP (+50)
#
# 🏆 Analyzing Tournament 45/100: tournament_20250609_164651
#    140th place: Jeremiah Schmutz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 46/100: tournament_20250609_164720
#    140th place: Kyle Lesniewicz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 47/100: tournament_20250609_164746
#    140th place: Jeremiah Schmutz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 48/100: tournament_20250609_164812
#    140th place: Kyle Lesniewicz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 49/100: tournament_20250609_164838
#    140th place: Corey Blankenship with 725 CP (+63)
#
# 🏆 Analyzing Tournament 50/100: tournament_20250609_164903
#    140th place: Tim Tipton with 720 CP (+58)
#
# 🏆 Analyzing Tournament 51/100: tournament_20250609_164928
#    140th place: Cyrus McCane with 720 CP (+58)
#
# 🏆 Analyzing Tournament 52/100: tournament_20250609_164955
#    140th place: Arjun Khadse with 720 CP (+58)
#
# 🏆 Analyzing Tournament 53/100: tournament_20250609_165021
#    140th place: Nico Gist with 716 CP (+54)
#
# 🏆 Analyzing Tournament 54/100: tournament_20250609_165046
#    140th place: Ming Weng with 720 CP (+58)
#
# 🏆 Analyzing Tournament 55/100: tournament_20250609_165111
#    140th place: Travis Beckwith with 720 CP (+58)
#
# 🏆 Analyzing Tournament 56/100: tournament_20250609_165135
#    140th place: Ramiro Galindo with 722 CP (+60)
#
# 🏆 Analyzing Tournament 57/100: tournament_20250609_165200
#    140th place: Mustafa Tobah with 717 CP (+55)
#
# 🏆 Analyzing Tournament 58/100: tournament_20250609_165226
#    140th place: Jeremiah Schmutz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 59/100: tournament_20250609_165250
#    140th place: Aaron Curry with 720 CP (+58)
#
# 🏆 Analyzing Tournament 60/100: tournament_20250609_165315
#    140th place: DC DeVos with 707 CP (+45)
#
# 🏆 Analyzing Tournament 61/100: tournament_20250609_165341
#    140th place: Orlando Karam with 717 CP (+55)
#
# 🏆 Analyzing Tournament 62/100: tournament_20250609_165408
#    140th place: Ramiro Galindo with 722 CP (+60)
#
# 🏆 Analyzing Tournament 63/100: tournament_20250609_165435
#    140th place: Yihao Chen with 720 CP (+58)
#
# 🏆 Analyzing Tournament 64/100: tournament_20250609_165503
#    140th place: Matt Bacnis with 720 CP (+58)
#
# 🏆 Analyzing Tournament 65/100: tournament_20250609_165530
#    140th place: Pearce Blend with 725 CP (+63)
#
# 🏆 Analyzing Tournament 66/100: tournament_20250609_165557
#    140th place: Aaron Curry with 720 CP (+58)
#
# 🏆 Analyzing Tournament 67/100: tournament_20250609_165625
#    140th place: Joseph Nawal with 720 CP (+58)
#
# 🏆 Analyzing Tournament 68/100: tournament_20250609_165653
#    140th place: Sammy Allen with 720 CP (+58)
#
# 🏆 Analyzing Tournament 69/100: tournament_20250609_165721
#    140th place: Jeremiah Schmutz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 70/100: tournament_20250609_165750
#    140th place: Benjamin Nackman with 715 CP (+53)
#
# 🏆 Analyzing Tournament 71/100: tournament_20250609_165819
#    140th place: Matt Bacnis with 720 CP (+58)
#
# 🏆 Analyzing Tournament 72/100: tournament_20250609_165849
#    140th place: Solomon Shurge with 721 CP (+59)
#
# 🏆 Analyzing Tournament 73/100: tournament_20250609_165918
#    140th place: Mustafa Tobah with 717 CP (+55)
#
# 🏆 Analyzing Tournament 74/100: tournament_20250609_165948
#    140th place: Dominic Viola with 719 CP (+57)
#
# 🏆 Analyzing Tournament 75/100: tournament_20250609_170018
#    140th place: Elsie Croizer with 720 CP (+58)
#
# 🏆 Analyzing Tournament 76/100: tournament_20250609_170048
#    140th place: Richard Yannow with 715 CP (+53)
#
# 🏆 Analyzing Tournament 77/100: tournament_20250609_170118
#    140th place: Ethan Yi with 720 CP (+58)
#
# 🏆 Analyzing Tournament 78/100: tournament_20250609_170148
#    140th place: Dean Nezam with 715 CP (+53)
#
# 🏆 Analyzing Tournament 79/100: tournament_20250609_170218
#    140th place: Aaron Curry with 720 CP (+58)
#
# 🏆 Analyzing Tournament 80/100: tournament_20250609_170249
#    140th place: Jeremiah Schmutz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 81/100: tournament_20250609_170320
#    140th place: Justin Kim with 715 CP (+53)
#
# 🏆 Analyzing Tournament 82/100: tournament_20250609_170351
#    140th place: Nick Dela Torre with 710 CP (+48)
#
# 🏆 Analyzing Tournament 83/100: tournament_20250609_170422
#    140th place: Sammy Allen with 720 CP (+58)
#
# 🏆 Analyzing Tournament 84/100: tournament_20250609_170453
#    140th place: Ethan Yi with 720 CP (+58)
#
# 🏆 Analyzing Tournament 85/100: tournament_20250609_170523
#    140th place: Hunter Butler with 720 CP (+58)
#
# 🏆 Analyzing Tournament 86/100: tournament_20250609_170554
#    140th place: Solomon Shurge with 721 CP (+59)
#
# 🏆 Analyzing Tournament 87/100: tournament_20250609_170626
#    140th place: Frank Luciano with 720 CP (+58)
#
# 🏆 Analyzing Tournament 88/100: tournament_20250609_170659
#    140th place: Hunter Butler with 720 CP (+58)
#
# 🏆 Analyzing Tournament 89/100: tournament_20250609_170731
#    140th place: Christian Chase with 720 CP (+58)
#
# 🏆 Analyzing Tournament 90/100: tournament_20250609_170804
#    140th place: Henry Thompson with 725 CP (+63)
#
# 🏆 Analyzing Tournament 91/100: tournament_20250609_170837
#    140th place: Solomon Shurge with 721 CP (+59)
#
# 🏆 Analyzing Tournament 92/100: tournament_20250609_170910
#    140th place: Hunter Butler with 720 CP (+58)
#
# 🏆 Analyzing Tournament 93/100: tournament_20250609_170942
#    140th place: Dre Alderette with 720 CP (+58)
#
# 🏆 Analyzing Tournament 94/100: tournament_20250609_171015
#    140th place: Orlando Karam with 717 CP (+55)
#
# 🏆 Analyzing Tournament 95/100: tournament_20250609_171047
#    140th place: Aaron Curry with 720 CP (+58)
#
# 🏆 Analyzing Tournament 96/100: tournament_20250609_171120
#    140th place: Jeremiah Schmutz with 720 CP (+58)
#
# 🏆 Analyzing Tournament 97/100: tournament_20250609_171154
#    140th place: Ajay Sridhar with 712 CP (+50)
#
# 🏆 Analyzing Tournament 98/100: tournament_20250609_171227
#    140th place: Richard Yannow with 715 CP (+53)
#
# 🏆 Analyzing Tournament 99/100: tournament_20250609_171301
#    140th place: George Illidge with 720 CP (+58)
#
# 🏆 Analyzing Tournament 100/100: tournament_20250609_171334
#    140th place: Dean Nezam with 715 CP (+53)
#
# 📊 140TH PLACE CUTOFF ANALYSIS - FROM 100 EXISTING TOURNAMENTS
# ======================================================================
# Baseline 140th place:    662 CP
# Minimum cutoff:          662 CP
# Maximum cutoff:          725 CP
# Mean cutoff:             717.8 CP
# Median cutoff:           720.0 CP
# Standard deviation:      7.0 CP
# Total range:             63 CP
#
# 📈 IMPACT OF TOURNAMENTS:
# Average impact per tournament: +55.8 CP
# Best case impact:              +63.0 CP
# Worst case impact:             +0.0 CP
# Percentage impact range:       +0.00% to +9.52%
#
# 🔢 ALL 140TH PLACE VALUES:
#    Tournament  1: 707 CP (+45) - DC DeVos
#    Tournament  2: 715 CP (+53) - Justin Kim
#    Tournament  3: 720 CP (+58) - George Illidge
#    Tournament  4: 712 CP (+50) - Ajay Sridhar
#    Tournament  5: 720 CP (+58) - Dre Alderette
#    Tournament  6: 720 CP (+58) - Christian Chase
#    Tournament  7: 720 CP (+58) - Sanjay Sundararajan
#    Tournament  8: 720 CP (+58) - Hunter Butler
#    Tournament  9: 662 CP (+0) - Ramiro Galindo
#    Tournament 10: 720 CP (+58) - Dre Alderette
#    Tournament 11: 700 CP (+38) - Jeremy Medina
#    Tournament 12: 717 CP (+55) - Mustafa Tobah
#    Tournament 13: 719 CP (+57) - jesse spencer
#    Tournament 14: 715 CP (+53) - Richard Yannow
#    Tournament 15: 720 CP (+58) - Ethan Yi
#    Tournament 16: 725 CP (+63) - Pearce Blend
#    Tournament 17: 720 CP (+58) - Jeremiah Schmutz
#    Tournament 18: 720 CP (+58) - Aaron Curry
#    Tournament 19: 714 CP (+52) - Vance Kelley
#    Tournament 20: 720 CP (+58) - Asher Johnson
#    Tournament 21: 725 CP (+63) - Jon Bieligk
#    Tournament 22: 712 CP (+50) - Ajay Sridhar
#    Tournament 23: 720 CP (+58) - Dre Alderette
#    Tournament 24: 720 CP (+58) - Hunter Butler
#    Tournament 25: 720 CP (+58) - Ethan Yi
#    Tournament 26: 710 CP (+48) - Eric Ridgeway
#    Tournament 27: 702 CP (+40) - Ramiro Galindo
#    Tournament 28: 720 CP (+58) - Jeremiah Schmutz
#    Tournament 29: 717 CP (+55) - Mustafa Tobah
#    Tournament 30: 717 CP (+55) - Orlando Karam
#    Tournament 31: 720 CP (+58) - Cameron Kawasaki
#    Tournament 32: 720 CP (+58) - Hunter Butler
#    Tournament 33: 720 CP (+58) - Frank Luciano
#    Tournament 34: 720 CP (+58) - Tiger Hickman
#    Tournament 35: 720 CP (+58) - Ethan Yi
#    Tournament 36: 720 CP (+58) - Christian Chase
#    Tournament 37: 720 CP (+58) - Dre Alderette
#    Tournament 38: 720 CP (+58) - Joseph Nawal
#    Tournament 39: 710 CP (+48) - Eric Ridgeway
#    Tournament 40: 720 CP (+58) - Joseph Nawal
#    Tournament 41: 720 CP (+58) - Dre Alderette
#    Tournament 42: 720 CP (+58) - Joseph Nawal
#    Tournament 43: 720 CP (+58) - Yihao Chen
#    Tournament 44: 712 CP (+50) - Ajay Sridhar
#    Tournament 45: 720 CP (+58) - Jeremiah Schmutz
#    Tournament 46: 720 CP (+58) - Kyle Lesniewicz
#    Tournament 47: 720 CP (+58) - Jeremiah Schmutz
#    Tournament 48: 720 CP (+58) - Kyle Lesniewicz
#    Tournament 49: 725 CP (+63) - Corey Blankenship
#    Tournament 50: 720 CP (+58) - Tim Tipton
#    Tournament 51: 720 CP (+58) - Cyrus McCane
#    Tournament 52: 720 CP (+58) - Arjun Khadse
#    Tournament 53: 716 CP (+54) - Nico Gist
#    Tournament 54: 720 CP (+58) - Ming Weng
#    Tournament 55: 720 CP (+58) - Travis Beckwith
#    Tournament 56: 722 CP (+60) - Ramiro Galindo
#    Tournament 57: 717 CP (+55) - Mustafa Tobah
#    Tournament 58: 720 CP (+58) - Jeremiah Schmutz
#    Tournament 59: 720 CP (+58) - Aaron Curry
#    Tournament 60: 707 CP (+45) - DC DeVos
#    Tournament 61: 717 CP (+55) - Orlando Karam
#    Tournament 62: 722 CP (+60) - Ramiro Galindo
#    Tournament 63: 720 CP (+58) - Yihao Chen
#    Tournament 64: 720 CP (+58) - Matt Bacnis
#    Tournament 65: 725 CP (+63) - Pearce Blend
#    Tournament 66: 720 CP (+58) - Aaron Curry
#    Tournament 67: 720 CP (+58) - Joseph Nawal
#    Tournament 68: 720 CP (+58) - Sammy Allen
#    Tournament 69: 720 CP (+58) - Jeremiah Schmutz
#    Tournament 70: 715 CP (+53) - Benjamin Nackman
#    Tournament 71: 720 CP (+58) - Matt Bacnis
#    Tournament 72: 721 CP (+59) - Solomon Shurge
#    Tournament 73: 717 CP (+55) - Mustafa Tobah
#    Tournament 74: 719 CP (+57) - Dominic Viola
#    Tournament 75: 720 CP (+58) - Elsie Croizer
#    Tournament 76: 715 CP (+53) - Richard Yannow
#    Tournament 77: 720 CP (+58) - Ethan Yi
#    Tournament 78: 715 CP (+53) - Dean Nezam
#    Tournament 79: 720 CP (+58) - Aaron Curry
#    Tournament 80: 720 CP (+58) - Jeremiah Schmutz
#    Tournament 81: 715 CP (+53) - Justin Kim
#    Tournament 82: 710 CP (+48) - Nick Dela Torre
#    Tournament 83: 720 CP (+58) - Sammy Allen
#    Tournament 84: 720 CP (+58) - Ethan Yi
#    Tournament 85: 720 CP (+58) - Hunter Butler
#    Tournament 86: 721 CP (+59) - Solomon Shurge
#    Tournament 87: 720 CP (+58) - Frank Luciano
#    Tournament 88: 720 CP (+58) - Hunter Butler
#    Tournament 89: 720 CP (+58) - Christian Chase
#    Tournament 90: 725 CP (+63) - Henry Thompson
#    Tournament 91: 721 CP (+59) - Solomon Shurge
#    Tournament 92: 720 CP (+58) - Hunter Butler
#    Tournament 93: 720 CP (+58) - Dre Alderette
#    Tournament 94: 717 CP (+55) - Orlando Karam
#    Tournament 95: 720 CP (+58) - Aaron Curry
#    Tournament 96: 720 CP (+58) - Jeremiah Schmutz
#    Tournament 97: 712 CP (+50) - Ajay Sridhar
#    Tournament 98: 715 CP (+53) - Richard Yannow
#    Tournament 99: 720 CP (+58) - George Illidge
#    Tournament 100: 715 CP (+53) - Dean Nezam
#
# 💾 Results saved:
#    Detailed data: existing_140th_analysis_20250609_171423.csv
#    Summary:       existing_140th_summary_20250609_171423.txt
#
# 📋 QUICK SUMMARY:
#    Tournaments analyzed: 100
#    Baseline 140th place: 662 CP
#    Cutoff range: 662 - 725 CP
#    Average cutoff: 717.8 CP ± 7.0
#    Most likely cutoff: 720 CP
#
# ✅ Results stored in variables 'cutoff_stats' and 'cutoff_values'
# 💾 Detailed files saved with timestamp

# %%
# Analyze 140th place cutoff across independent scenarios
num_scenarios = 10  # Adjust as needed

cutoff_analysis = sim.track_140th_place_experiment(
    num_simulations=num_scenarios,
    tournament_size=None,  # Uses random 3,700-4,000 sizes
    save_results=True
)

print(f"\n🎯 140th Place Cutoff Analysis Complete!")
print(f"📁 Results saved to timestamped CSV and TXT files")
# Out:
# 🎯 140TH PLACE CHAMPIONSHIP POINTS EXPERIMENT - INDEPENDENT SCENARIOS
# ======================================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Analyze 140th place cutoff across independent scenarios
#       2 num_scenarios = 10  # Adjust as needed
# ----> 4 cutoff_analysis = sim.track_140th_place_experiment(
#       5     num_simulations=num_scenarios,
#       6     tournament_size=None,  # Uses random 3,700-4,000 sizes
#       7     save_results=True
#       8 )
#      10 print(f"\n🎯 140th Place Cutoff Analysis Complete!")
#      11 print(f"📁 Results saved to timestamped CSV and TXT files")
#
# File ~/Documents/Code/event-sim/clean_tournament_sim.py:1056, in TournamentSimulator.track_140th_place_experiment(self, num_simulations, tournament_size, save_results)
#    1054 print(f"🎯 140TH PLACE CHAMPIONSHIP POINTS EXPERIMENT - INDEPENDENT SCENARIOS")
#    1055 print("=" * 70)
# -> 1056 print(f"Running {num_simulations} INDEPENDENT tournaments with {tournament_size:,} players each")
#    1057 print(f"Each tournament starts from the same baseline (no cumulative effects)")
#    1058 print(f"Goal: Predict range of possible 140th place cutoffs")
#
# TypeError: unsupported format string passed to NoneType.__format__

# %% [raw]
# ## 🔍 **ANALYZE RESULTS**
#
# Examine specific players and performance patterns.

# %%
# Database overview
sim.database_stats()
# Out:
# 📊 DATABASE STATISTICS
# ========================================
# Total players: 4,000
# Players with tournament history: 3,995
# Unique tournaments recorded: 19
# Low CP players (≤331): 3,350
# High CP players (≥332): 650
# {'total_players': 4000,
#  'players_with_tournament_history': 3995,
#  'unique_tournaments_recorded': 19,
#  'low_cp_players': 3350,
#  'high_cp_players': 650}

# %%
# Top performers across all tournaments
sim.get_top_performers(min_tournaments=5)

# %%
# Analyze specific player (replace with any player name)
player_name = "Henry Chao"  # Change this to any player
sim.quick_analysis(player_name)

# %%
# Check current NA championship standings (top 150)
if sim.na_manager:
    current_standings = sim.na_manager.generate_final_rankings(top_n=150)
    
    # Show 140th place specifically
    place_140 = current_standings.iloc[139]  # 140th place (0-indexed)
    print(f"\n🎯 CURRENT 140TH PLACE:")
    print(f"Player: {place_140['Top X Name']}")
    print(f"Championship Points: {place_140['Total_CP']:,}")
    print(f"Top X CP: {place_140['Top_X_CP']:,}")
    print(f"Locals CP: {place_140['Locals CP']:,}")
else:
    print("❌ NA standings tracking not enabled")

# %% [raw]
# ## 📋 **EXPERIMENT SUMMARY**
#
# Quick reference for experiment parameters and results.

# %%
# Print experiment summary
stats = sim.database_stats()

print(f"📋 EXPERIMENT SUMMARY")
print(f"=" * 40)
print(f"Total Tournaments: {stats['unique_tournaments_recorded']}")
print(f"Players Tracked: {stats['total_players']:,}")
print(f"Players with History: {stats['players_with_tournament_history']:,}")
print(f"Tournament Size Range: 3,700-4,000 players (randomized)")
print(f"Data Completeness: {stats['players_with_tournament_history']/stats['total_players']*100:.1f}%")

print(f"\n💾 All data accessible via:")
print(f"  • sim.quick_analysis('Player Name')")
print(f"  • sim.get_top_performers()")
print(f"  • sim.database_stats()")
print(f"  • Database files with complete match history")
